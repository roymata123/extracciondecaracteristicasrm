# %% [markdown]
# <a href="https://colab.research.google.com/github/roymata123/extracciondecaracteristicasrm/blob/main/Extraccion_de_caracteristicas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librearias
import pandas as pd
import numpy as nd
#Librerias para el manejo de datos
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl
#Librerias para la graficacion

# %%
#Instalamos libreria para analisis de variables categoricas
# %pip install funpymodeling

# %%
#Cargar archivo scv desde equipo
from google.colab import files
files.upload()
#Seleccion del archivo microretatiles para su edicion en el doc

# %%
#Codigo para visualizar todas las columnas
#Ajustar maximo de columnas
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
#Carga desde un archivo .xlsx sin indice
Micro_Retailer= pd.read_excel("microretailer_mit_lift_lab.xlsx")
Micro_Retailer

# %%
#Identificar valores nulos por columna
valores_nulos=Micro_Retailer.isnull().sum()
valores_nulos

# %%
#Verificamos la informacion del dataframe
Micro_Retailer.info()
#int64 y float64 es numerica
#object es de tipo texto

# %%
#Imprimimos los primeros 5 registros del Dataframe
Micro_Retailer.head()

# %%
#Obtengo un analisis univariado de las variables categoricas
freq_tbl(Micro_Retailer)

# %%
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table1= freq_tbl(Micro_Retailer["157_frequency_organize_shelves"])
table1
# Out:
#   157_frequency_organize_shelves  frequency  percentage  cumulative_perc
# 0                   Semanalmente         40    0.233918         0.416667
# 1                    Diariamente         32    0.187135         0.750000
# 2                          Nunca          8    0.046784         0.833333
# 3                   Mensualmente          7    0.040936         0.906250
# 4                 Quincenalmente          5    0.029240         0.958333
# 5                     Anualmente          2    0.011696         0.979167
# 6                 Semestralmente          1    0.005848         0.989583
# 7                    No se tiene          1    0.005848         1.000000

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
Filtro1= table1[table1["frequency"]>1]
Filtro1
# Out:
#   157_frequency_organize_shelves  frequency  percentage  cumulative_perc
# 0                   Semanalmente         40    0.233918         0.416667
# 1                    Diariamente         32    0.187135         0.750000
# 2                          Nunca          8    0.046784         0.833333
# 3                   Mensualmente          7    0.040936         0.906250
# 4                 Quincenalmente          5    0.029240         0.958333
# 5                     Anualmente          2    0.011696         0.979167

# %%
#Ajusto indice de mi DATAFRAME
Filtro_index=Filtro1.set_index("157_frequency_organize_shelves")#ajustamos esta columna como una de tipo indice
Filtro_index
# Out:
#                                 frequency  percentage  cumulative_perc
# 157_frequency_organize_shelves
# Semanalmente                           40    0.233918         0.416667
# Diariamente                            32    0.187135         0.750000
# Nunca                                   8    0.046784         0.833333
# Mensualmente                            7    0.040936         0.906250
# Quincenalmente                          5    0.029240         0.958333
# Anualmente                              2    0.011696         0.979167

# %%
#Realizamos le pastel del Dataframe filtrado
Filtro_index["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-39-9dc2eb539465> in <cell line: 2>()
#       1 #Realizamos le pastel del Dataframe filtrado
# ----> 2 Filtro_index["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918             ]
#     919         else:
# --> 920             raise TypeError(
#     921                 f"Called plot accessor for type {type(data).__name__}, "
#     922                 "expected Series or DataFrame"
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1884
#    1885     eps = entry_points()
# -> 1886     key = "pandas_plotting_backends"
#    1887     # entry_points lost dict API ~ PY 3.10
# ...

# %%
#filtro PARA las vaiables cuantitativas
Micro2=Micro_Retailer.iloc[:,[54,55,56,67,68,69,71,72,73,74,75,76,77,78,79,80,81,83,85,86]]#VAIRABLES cuantitativas, columnnas
Micro2

# %%
Micro2.info()

# %%
#Sustituir valores nulos con promedio o media
#Micro2["268_number_fridges"]=Micro2["268_number_fridges"].fillna(round(Micro_Retailer["268_number_fridges"].mean()))

#Sustituir valores nulos por un string en  concreto
Micro2["227_agreement_ecommerce_platforms"] =Micro2["227_agreement_ecommerce_platforms"].fillna("NONE")#1
Micro2["60_services"] =Micro2["60_services"].fillna("NONE")#2
Micro2["315_frequency_topups"] =Micro2["315_frequency_topups"].fillna("NONE")#3
Micro2["312_payment_of_utilities"] =Micro2["312_payment_of_utilities"].fillna("NONE")#4
Micro2["313_home_deliveries"] =Micro2["313_home_deliveries"].fillna("NONE")#5
Micro2["314_reception_delivery_packages"] =Micro2["314_reception_delivery_packages"].fillna("NONE")#6
Micro2["44_willingness_inventory_management_suppliers"] =Micro2["44_willingness_inventory_management_suppliers"].fillna("NONE")#7
Micro2["45_willingness_reorder_suppliers"] =Micro2["45_willingness_reorder_suppliers"].fillna("NONE")#8
Micro2["46_willingness_reorder_suppliers_variety"] =Micro2["46_willingness_reorder_suppliers_variety"].fillna("NONE")#9
Micro2["47_willingness_reorder_suppliers_lower_prices"] =Micro2["47_willingness_reorder_suppliers_lower_prices"].fillna("NONE")#10
Micro2["43_willingness_share_sales_data_suppliers"] =Micro2["43_willingness_share_sales_data_suppliers"].fillna("NONE")#11
Micro2["58_willingness_share_sales_data_mse"] =Micro2["58_willingness_share_sales_data_mse"].fillna("NONE")#12
Micro2["59_willingness_share_sales_data_mse_better_prices"] =Micro2["59_willingness_share_sales_data_mse_better_prices"].fillna("NONE")#13
Micro2["172_supplier_frequency"] =Micro2["172_supplier_frequency"].fillna("NONE")#14
Micro2["185_place_orders_suppliers"] =Micro2["185_place_orders_suppliers"].fillna("NONE")#15
Micro2["53_special_conditions_suppliers"] =Micro2["53_special_conditions_suppliers"].fillna("NONE")#16
Micro2["278_credit_interest"] =Micro2["278_credit_interest"].fillna("NONE")#17
Micro2["277_payment_method_suppliers"] =Micro2["277_payment_method_suppliers"].fillna("NONE")#18
Micro2["279_changes_procurement_pandemic"] =Micro2["279_changes_procurement_pandemic"].fillna("NONE")#19
Micro2["157_frequency_organize_shelves"] =Micro2["157_frequency_organize_shelves"].fillna("NONE")#20

#data3["otros"]=data3["otros"].fillna(round(data2["otros"].mean()))

# %%
#Identificar valores nulos por columna
valores_nulosM2=Micro2.isnull().sum()
valores_nulosM2

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["227_agreement_ecommerce_platforms"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("227_agreement_ecommerce_platforms")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["60_services"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("60_services")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["315_frequency_topups"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("315_frequency_topups")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["312_payment_of_utilities"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("312_payment_of_utilities")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["313_home_deliveries"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("313_home_deliveries")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["314_reception_delivery_packages"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("314_reception_delivery_packages")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["44_willingness_inventory_management_suppliers"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("44_willingness_inventory_management_suppliers")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["45_willingness_reorder_suppliers"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("45_willingness_reorder_suppliers")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["46_willingness_reorder_suppliers_variety"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("46_willingness_reorder_suppliers_variety")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["47_willingness_reorder_suppliers_lower_prices"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("47_willingness_reorder_suppliers_lower_prices")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["43_willingness_share_sales_data_suppliers"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("43_willingness_share_sales_data_suppliers")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["58_willingness_share_sales_data_mse"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("58_willingness_share_sales_data_mse")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["59_willingness_share_sales_data_mse_better_prices"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("59_willingness_share_sales_data_mse_better_prices")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["172_supplier_frequency"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("172_supplier_frequency")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["185_place_orders_suppliers"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("185_place_orders_suppliers")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["53_special_conditions_suppliers"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("53_special_conditions_suppliers")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["278_credit_interest"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("278_credit_interest")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["277_payment_method_suppliers"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("277_payment_method_suppliers")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["279_changes_procurement_pandemic"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("279_changes_procurement_pandemic")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_1= freq_tbl(Micro_Retailer["157_frequency_organize_shelves"])
Filtro_1= table_1[table_1["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_1=Filtro_1.set_index("157_frequency_organize_shelves")#ajustamos esta columna como una de tipo indice
#Identificar valores nulos por columna
#Filtro_index_1
#valores_nulos_1=Filtro_index_1.isnull().sum()
#valores_nulos_1
#Realizamos le pastel del Dataframe filtrado
Filtro_index_1["frequency"].plot(kind= "pie", figsize=(20,10),shadow= True, autopct="%.1f %%")

# %%
#Obtengo un analisis univariado de las variables categoricas, una slecionada
#Obtengo un analisis univariado de las variables categoricas, una en especifico
table_7= freq_tbl(Micro_Retailer[""])
Filtro_7= table_7[table_7["frequency"]>1] #Seleccionamos los valores mayores a 1 para que no haya exceso de datos, ya que es solo muestra
Filtro_index_7=Filtro_7.set_index("")#ajustamos esta columna como una de tipo indice
#Filtro_index_7
#Realizamos le pastel del Dataframe filtrado
Filtro_index_7["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")#Ajusto indice de mi DATAFRAME
Filtro_index=Filtro1.set_index("214_customer_relationship_tools")#ajustamos esta columna como una de tipo indice
Filtro_index
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind= "bar", width=1, figsize=(10,4))
plt.title("Herramientas de relación con los clientes")
plt.xlabel("Tipo de herramienta")
plt.ylabel("Frecuencia")
#Realizamos el grafico de dispersion
Filtro_index.plot("frequency", "cumulative_perc", kind= "scatter")
#Realizamos el grafico de area del Dataframe filtrado
Filtro_index.plot(kind= "area", figsize=(10,4), alpha=0.5)
#Realizamos le pastel del Dataframe filtrado
Filtro_index["frequency"].plot(kind= "pie", figsize=(10,5),shadow= True, autopct="%0.1f %%")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             #  the TypeError.
# -> 3802             self._check_indexing_error(key)
#    3803             raise
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-4709cd9f2db3> in <cell line: 3>()
# ...
